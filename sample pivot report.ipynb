# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Import the data from CSV

# %%
prices = pd.read_csv('price_paid_records.csv')

# %%
prices
# Out:
#                    Transaction unique identifier     Price  Date of Transfer  \
# 21906462  {50F18103-E682-9FD5-E050-A8C063054923}  98900000  2016-11-24 00:00
# 22186198  {50F18103-F5E4-9FD5-E050-A8C063054923}  98765391  2017-02-09 00:00
# 22346117  {4E95D758-283E-EDA1-E050-A8C0630539E2}  98446300  2017-04-06 00:00
# 20231796  {23B6165F-33A2-FCF4-E050-A8C0620577FA}  98250000  2015-10-21 00:00
# 22312341  {5376B386-560C-34C1-E053-6B04A8C09FF6}  97630000  2017-05-25 00:00
# ...                                          ...       ...               ...
# 1266424   {2A289E9F-116F-CDC8-E050-A8C063054829}         1  1996-11-18 00:00
# 22304975  {50F18103-7165-9FD5-E050-A8C063054923}         1  2017-03-03 00:00
# 1227479   {2A289E9E-48D0-CDC8-E050-A8C063054829}         1  1996-06-07 00:00
# 2139442   {2A289E9D-32EB-CDC8-E050-A8C063054829}         1  1997-11-04 00:00
# 3370705   {2A289E9D-149B-CDC8-E050-A8C063054829}         1  1998-05-22 00:00
#
# ...

# %% [markdown]
# Pivot data indexed against county displaying median house price data in accending order

# %%
county = prices.pivot_table(values='Price',  index='County',  aggfunc='median')
county.sort_values(by=['Price'], ascending=True, inplace=True )
county
# Out:
#                            Price
# County
# WEST GLAMORGAN           38900.0
# MID GLAMORGAN            39000.0
# DYFED                    41000.0
# HUMBERSIDE               41500.0
# CLEVELAND                42500.0
# ...                          ...
# CENTRAL BEDFORDSHIRE    220000.0
# WOKINGHAM               222000.0
# ISLES OF SCILLY         230000.0
# SURREY                  230000.0
# WINDSOR AND MAIDENHEAD  249950.0
#
# [127 rows x 1 columns]

# %% [markdown]
# Display data as bar chart

# %%
county.plot(kind = 'bar',figsize=(30, 20), rot=90)
